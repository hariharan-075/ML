# %% [markdown]
# <a href="https://colab.research.google.com/github/hariharan-075/ML/blob/main/2420080075_ML_Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Write a Python Program to Print Hello World !
print("Hello World")
# Out:
# Hello World

# %%
#Write a python program demonstrating numeric String and Character types in Python
print("Numeric Type: " , type(56))
print("String Type: " , type("Hello"))
# Out:
# Numeric Type:  <class 'int'>
# String Type:  <class 'str'>

# %%
#Display Data tpe of a Variable
print("Numeric Type: " , type(56))
# Out:
# Numeric Type:  <class 'int'>

# %%
#write a python demonstrating multiple assignments
a, c , b = 5 , "A", 10
print(a , c, b)
# Out:
# 5 A 10

# %%
#Create a list with any 4 fruits and print them as list
fruits = ["Apple", "Banana", "Mango", "Orange"]
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango', 'Orange']

# %%
#write a python program to demonstrate dictionary in python and dictionary with car brand car model and year of manufacture
students = {
    "A":85,
    "B":90,
    "C":78,
}
highest_scorer = max(students, key=students.get)
print("Highest scorer is:", highest_scorer, "with score", students[highest_scorer])
# Out:
# Highest scorer is: B with score 90

# %%
#Uisng math and random libraries
import math
import random
print("Square root of 25 is:", math.sqrt(25))
print("Random number between 1 and 10:", random.randint(1, 100))
# Out:
# Square root of 25 is: 5.0
# Random number between 1 and 10: 96

# %%
#Sum of digits
num = 1234
sum_of_digits = sum(int(digit) for digit in str(num))
print("Sum of digits in", num, "is:", sum_of_digits)
# Out:
# Sum of digits in 1234 is: 10

# %%
#Indexing and Slicing
my_list = [10, 20, 30, 40, 50]
print(my_list[1:4])  # Slicing from index 1 to 3
print(my_list[0])   # Accessing the last element
# Out:
# [20, 30, 40]
# 10
